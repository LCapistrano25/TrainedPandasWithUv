# %%
import random as rd
import pandas as pd

# %%
data = [rd.randint(0, 100) for _ in range(25)]

# %%
s = pd.Series(data)
s
# Out:
# 0     80
# 1     25
# 2     21
# 3     21
# 4     88
# 5      0
# 6     34
# 7     19
# 8     86
# 9     29
# 10    93
# 11    61
# 12    70
# 13    85
# 14    38
# 15    56
# 16    75
# 17    62
# 18    61
# 19    79
# 20    35
# 21    80
# 22    74
# 23    94
# 24    59
# dtype: int64
